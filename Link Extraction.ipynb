# %%
# Importing Libraries

import time
import os
from datetime import datetime
from secedgar.filings import Filing, FilingType
from secedgar.cik_lookup import get_cik_map
time.sleep(10)
# os.getcwd()

import bs4 as bs
import requests
import pandas as pd
import re

# %%
# To avoid 'user limit exceeded'

import requests_random_user_agent

s = requests.Session()
print(s.headers['User-Agent'])
# Out:
# Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.85 Safari/537.36

# %%
cik = get_cik_map()['ticker']
print("Total number of companies are", len(cik))

# outputPath = "C:\\Users\\ARYAN\\Desktop\\9th Sem\\Project"
# Out:
# Total number of companies are 13023

# %%
#  Downloading 10-K files using SEC Library

'''
start = time.time()

total = 0

for idx, ck in enumerate(list(cik.keys())[:11]):
    print(idx, ck, cik[ck])
    
    temp = Filing(cik_lookup = list(cik.keys())[idx],
                filing_type = FilingType.FILING_10K,
                start_date = datetime(2016, 1, 1),
                end_date = datetime(2022, 1, 1),
                user_agent = 'aryanpcm@gmail.com')
    
    try:
        print("Filings found")
        temp.save(outputPath)
        
    except:
        total += 1
        print("No filings found")

end = time.time()
print('Total Time taken -----', round((end-start)/60, 2), 'minutes')'''
# Out:
# '\nstart = time.time()\n\ntotal = 0\n\nfor idx, ck in enumerate(list(cik.keys())[:11]):\n    print(idx, ck, cik[ck])\n    \n    temp = Filing(cik_lookup = list(cik.keys())[idx],\n                filing_type = FilingType.FILING_10K,\n                start_date = datetime(2016, 1, 1),\n                end_date = datetime(2022, 1, 1),\n                user_agent = \'aryanpcm@gmail.com\')\n    \n    try:\n        print("Filings found")\n        temp.save(outputPath)\n        \n    except:\n        total += 1\n        print("No filings found")\n\nend = time.time()\nprint(\'Total Time taken -----\', round((end-start)/60, 2), \'minutes\')'

# %%
list_of_companies = cik.keys()
lookup_table = cik

# %%
# Checking the content of cik
cik
# Out:
# {'AAPL': '320193',
#  'MSFT': '789019',
#  'GOOG': '1652044',
#  'AMZN': '1018724',
#  'GE': '40545',
#  'TSLA': '1318605',
#  'BRK-A': '1067983',
#  'TSM': '1046179',
#  'TCEHY': '1293451',
#  'V': '1403161',
#  'BABA': '1577552',
#  'JPM': '19617',
#  'JNJ': '200406',
#  'WMT': '104169',
#  'LVMUY': '824046',
#  'SPY': '884394',
#  'UNH': '731766',
#  'MA': '1141391',
#  'BAC': '70858',
#  'HD': '354950',
#  'PG': '80424',
#  'ASML': '937966',
#  'DIS': '1744489',
#  'PYPL': '1633917',
#  'ADBE': '796343',
#  'PFE': '78003',
#  'CMCSA': '1166691',
#  'NKE': '320187',
#  'LLY': '59478',
#  'ORCL': '1341439',
#  'TM': '1094517',
#  'KO': '21344',
#  'XOM': '34088',
#  'NVO': '353278',
#  'CSCO': '858877',
#  'IDCBY': '1445468',
#  'CRM': '1108524',
#  'VZ': '732712',
#  'NFLX': '1065280',
#  'DHR': '313616',
#  'ABT': '1800',
#  'PEP': '77476',
#  'INTC': '50863',
#  'CHDRY': '1450488',
#  'TMO': '97745',
#  'NVS': '1114448',
#  'ABBV': '1551152',
#  'ACN': '1467373',
#  'CIHKY': '1495688',
#  'WFC': '72971',
#  'T': '732717',
#  'AVGO': '1730168',
#  'COST': '909832',
#  'MRK': '310158',
#  'CVX': '93410',
#  'MS': '895421',
#  'BHP': '811809',
#  'VWDRY': '1330306',
#  'SHOP': '1594805',
#  'CICHY': '1445474',
#  'MCD': '63908',
#  'MDT': '1613103',
#  'TMUS': '1283699',
#  'TXN': '97476',
#  'SAP': '1000184',
#  'UPS': '1090727',
#  'QCOM': '804328',
#  'NEE': '753308',
#  'HESAY': '1436949',
#  'HON': '773840',
#  'LIN': '1707925',
#  'PM': '1413329',
#  'BBL': '1171264',
#  'RDS-A': '1306965',
#  'ACGBY': '1501437',
#  'BMY': '14272',
#  'AZN': '901832',
#  'SE': '1703399',
#  'UNP': '100885',
#  'C': '831001',
#  'MRNA': '1682852',
#  'UL': '217410',
#  'RY': '1000275',
#  'INTU': '896878',
#  'CHTR': '1091667',
#  'QQQ': '1067839',
#  'RTNTF': '887028',
#  'BLK': '1364742',
#  'HDB': '1144967',
#  'GS': '886982',
#  'SBUX': '829224',
#  'SCHW': '316709',
#  'LOW': '60667',
#  'AMD': '2488',
#  'BA': '12927',
#  'AXP': '4962',
#  'AMGN': '318154',
#  'PTR': '1108329',
#  'RTX': '101829',
#  'TGT': '27419',
#  'SNY': '1121404',
#  'AMT': '1053507',
#  'IBM': '51143',
#  'SONY': '313838',
#  'BACHY': '1378999',
#  'TD': '947263',
#  'NVDA': '1045810',
#  'RIO': '863064',
#  'BUD': '1668717',
#  'TTE': '879764',
#  'AMAT': '6951',
#  'SQ': '1512673',
#  'DE': '315189',
#  'CAT': '18230',
#  'EL': '1001250',
#  'ISRG': '1035267',
#  'BYDDY': '1445162',
#  'DEO': '835403',
#  'MMM': '66740',
#  'PPRUY': '1445465',
#  'HSBC': '1089113',
#  'NOW': '1373715',
#  'CVS': '64803',
#  'SNAP': '1564408',
#  'IDEXY': '1438656',
#  'JD': '1549802',
#  'SPGI': '64040',
#  'LFC': '1268896',
#  'EADSY': '1378580',
#  'GSK': '1131399',
#  'PDD': '1737806',
#  'VALE': '917851',
#  'ZM': '1585521',
#  'SFTBY': '1065521',
#  'INFY': '1067491',
#  'LMT': '936468',
#  'SYK': '310764',
#  'SBGSY': '923734',
#  'PLD': '1045609',
#  'ZTS': '1555280',
#  'DMLRY': '1067318',
#  'ABNB': '1559720',
#  'MELI': '1099590',
#  'ADP': '8670',
#  'ANTM': '1156039',
#  'MO': '764180',
#  'GILD': '882095',
#  'MDLZ': '1103982',
#  'BAM': '1001085',
#  'BKNG': '1075531',
#  'USB': '36104',
#  'SNOW': '1640147',
#  'BTI': '1303523',
#  'BP': '313807',
#  'TJX': '109198',
#  'ESLOY': '1085922',
#  'TEAM': '1650372',
#  'CCI': '1051470',
#  'LRCX': '707549',
#  'DUK': '1326160',
#  'BNTX': '1776985',
#  'FIS': '1136893',
#  'SWGAY': '1438845',
#  'CB': '896159',
#  'AIQUY': '1161167',
#  'SHW': '89800',
#  'BX': '1393818',
#  'HCA': '860730',
#  'HKXCY': '1445476',
#  'CTA-PA': '30554',
#  'PNC': '713676',
#  'ATLCY': '748954',
#  'COF': '927628',
#  'ENB': '895728',
#  'MU': '723125',
#  'UBER': '1543151',
#  'BNS': '9631',
#  'MMC': '62709',
#  'GM': '1467858',
#  'TFC': '92230',
#  'DELL': '1571996',
#  'ABB': '1091587',
#  'CNI': '16868',
#  'ILMN': '1110803',
#  'PSTVY': '1689565',
#  'FISV': '798354',
#  'FDX': '1048911',
#  'GWLLY': '1536278',
#  'CME': '1156375',
#  'ITW': '49826',
#  'COP': '1163165',
#  'EQIX': '1101239',
#  'PBR': '1119639',
#  'ADSK': '769397',
#  'BDX': '10795',
#  'CI': '1739940',
#  'MUFG': '67088',
#  'MCO': '1059556',
#  'CFRUY': '948401',
#  'EW': '1099800',
#  'SO': '92122',
#  'SNP': '1123658',
#  'FRCOY': '1446595',
#  'DKILY': '1446519',
#  'WBK': '719245',
#  'KDDIY': '1106215',
#  'NJDCY': '1158967',
#  'SHECY': '1442651',
#  'STLA': '1605484',
#  'EQNR': '1140625',
#  'CL': '21665',
#  'IBN': '1103838',
#  'NSC': '702165',
#  'COIN': '1679788',
#  'ETN': '1551182',
#  'REGN': '872589',
#  'ICE': '1571949',
#  'BMO': '927971',
#  'SAN': '891478',
#  'VMW': '1124610',
#  'ATVI': '718877',
#  'WM': '823768',
#  'APD': '2969',
#  'BSX': '885725',
#  'D': '715957',
#  'NIO': '1736541',
#  'ECL': '31462',
#  'AON': '315293',
#  'ADI': '6281',
#  'DNNGY': '1679771',
#  'TOELY': '1443276',
#  'CVNA': '1690820',
#  'EMR': '32604',
#  'GLNCY': '1524684',
#  'TWLO': '1447669',
#  'CHGCY': '1453934',
#  'DASH': '1792789',
#  'VCISY': '1065198',
#  'UBS': '1610520',
#  'NXPI': '1413447',
#  'NOC': '1133421',
#  'WDAY': '1327811',
#  'RELX': '929869',
#  'LZAGY': '1446711',
#  'NTES': '1110646',
#  'IDXX': '874716',
#  'CPNG': '1834584',
#  'GD': '40533',
#  'BSBR': '1471055',
#  'AMX': '1129137',
#  'TRI': '1075124',
#  'LNSTY': '1439584',
#  'PDRDY': '899108',
#  'PGR': '80661',
#  'HMC': '715153',
#  'RACE': '1648416',
#  'DG': '29534',
#  'DOCU': '1261333',
#  'ITUB': '1132597',
#  'PSA': '1393311',
#  'DNZOY': '1446598',
#  'LULU': '1397187',
#  'MET': '1099219',
#  'SAFRY': '1364012',
#  'RBGLY': '1420798',
#  'ALGN': '1097149',
#  'FCX': '831259',
#  'ING': '1039765',
#  'WFAFY': '1436381',
#  'IFNNY': '1107457',
#  'F': '37996',
#  'PUK': '1116578',
#  'CM': '1045520',
#  'MRAAY': '1450468',
#  'HUM': '49071',
#  'CRWD': '1535527',
#  'CMG': '1058090',
#  'TAK': '1395064',
#  'JCI': '833444',
#  'MSCI': '1408198',
#  'MNST': '865752',
#  'BIIB': '875045',
#  'CSUAY': '1445470',
#  'INFO': '1598014',
#  'BIDU': '1329099',
#  'TWTR': '1418091',
#  'SXYAY': '1575851',
#  'ROP': '882835',
#  'KLAC': '319201',
#  'EBAY': '1065088',
#  'TEL': '1385157',
#  'KDP': '1418135',
#  'SCCO': '1001838',
#  'GPN': '1123360',
#  'MRVL': '1835632',
#  'VRTX': '875320',
#  'FTNT': '1262039',
#  'A': '1090872',
#  'EPD': '1061219',
#  'VEEV': '1393052',
#  'CARR': '1783180',
#  'ABEV': '1565025',
#  'TROW': '1113169',
#  'DANOY': '1048515',
#  'IQV': '1478242',
#  'WIT': '1123799',
#  'BBD': '1160330',
#  'DOW': '1751788',
#  'DXCM': '1093557',
#  'BK': '1390777',
#  'VLVLY': '753762',
#  'SMFG': '1022837',
#  'EXC': '1109357',
#  'ROKU': '1428439',
#  'NGG': '1004315',
#  'NEM': '1164727',
#  'VOD': '839923',
#  'LHX': '202058',
#  'TRP': '1232384',
#  'AIG': '5272',
#  'OLCLY': '1545460',
#  'PLTR': '1321655',
#  'TT': '1466258',
#  'BCE': '718940',
#  'KHC': '1637459',
#  'ITOCY': '355363',
#  'KMB': '55785',
#  'GVDNY': '1121631',
#  'NTOIY': '1436791',
#  'BCMXY': '1447011',
#  'BBVA': '842180',
#  'RBLX': '1315098',
#  'AEP': '4904',
#  'VNJA': '1532383',
#  'SNPS': '883241',
#  'DLR': '1297996',
#  'LYG': '1160106',
#  'APTV': '1521332',
#  'APH': '820313',
#  'ROST': '745732',
#  'CRARY': '1279967',
#  'FANUY': '1446596',
#  'E': '1002242',
#  'BCS': '312069',
#  'NVZMY': '1131345',
#  'MAR': '1048286',
#  'GLD': '1222333',
#  'SPG': '1063761',
#  'KNYJY': '1436793',
#  'WBA': '1618921',
#  'PRU': '1137774',
#  'CDNS': '813672',
#  'PAYX': '723531',
#  'ZIJMY': '1459580',
#  'ORLY': '898173',
#  'CRH': '849395',
#  'DFS': '1393612',
#  'MCHP': '827054',
#  'KHNGY': '1451287',
#  'CTAS': '723254',
#  'STZ': '16918',
#  'DDOG': '1561550',
#  'JMHLY': '870016',
#  'ALL': '899051',
#  'SRE': '1032208',
#  'DD': '1666700',
#  'RMD': '943819',
#  'CTSH': '1058290',
#  'SYY': '96021',
#  'PHG': '313216',
#  'CODYY': '1012037',
#  'OVCHY': '1448817',
#  'EA': '712515',
#  'YUM': '1041061',
#  'PPG': '79879',
#  'ECIFY': '1387438',
#  'SPOT': '1639920',
#  'VONOY': '1652630',
#  'TRV': '86312',
#  'SLB': '87347',
#  'MFC': '1086888',
#  'MSI': '68505',
#  'SVNDY': '1359519',
#  'AFL': '4977',
#  'CNQ': '1017413',
#  'IFF': '51253',
#  'KMI': '1506307',
#  'STM': '932787',
#  'CHWY': '1766502',
#  'OTIS': '1781335',
#  'RSG': '1060391',
#  'ERIC': '717826',
#  'CLPBY': '1294325',
#  'SBAC': '1034054',
#  'PH': '76334',
#  'MPC': '1510295',
#  'EOG': '821189',
#  'KKR': '1404912',
#  'VIVHY': '1127055',
#  'RKT': '1805284',
#  'CICOY': '1445161',
#  'CGEMY': '1084656',
#  'NUE': '73309',
#  'XEL': '72903',
#  'HSY': '47111',
#  'BAX': '10456',
#  'NET': '1477333',
#  'CNC': '1071739',
#  'MT': '1243429',
#  'MTCH': '891103',
#  'ROK': '1024478',
#  'GIS': '40704',
#  'MTCPY': '1159204',
#  'ASAZY': '1253493',
#  'MFG': '1335730',
#  'MTD': '1037646',
#  'OKTA': '1660134',
#  'GELYY': '1474968',
#  'PANW': '1327567',
#  'HCMLY': '948696',
#  'GOLD': '756894',
#  'PXD': '1038357',
#  'U': '1810806',
#  'PINS': '1506293',
#  'ASHTY': '1518258',
#  'WELL': '766704',
#  'NTR': '1725964',
#  'FRC': '1132979',
#  'ALC': '1167379',
#  'DHI': '882184',
#  'AZO': '866787',
#  'LYB': '1489393',
#  'XLNX': '743988',
#  'CMI': '26172',
#  'EPAM': '1352010',
#  'ADM': '7084',
#  'HPQ': '47217',
#  'NOK': '924613',
#  'KBCSY': '1411133',
#  'LBRDA': '1611983',
#  'NWG': '844150',
#  'GLW': '24741',
#  'HLT': '1585689',
#  'HNNMY': '1396282',
#  'AHCHY': '1448987',
#  'RHT': '1087423',
#  'ZS': '1713683',
#  'LEN': '920760',
#  'CPRT': '900075',
#  'CTVA': '1755672',
#  'TDG': '1260221',
#  'WCN': '1318220',
#  'AWK': '1410636',
#  'BF-A': '14693',
#  'CHT': '1132924',
#  'IAU': '1278680',
#  'PTON': '1639825',
#  'POAHY': '1450346',
#  'PEG': '788784',
#  'ODFL': '878927',
#  'GRMN': '1121788',
#  'PSX': '1534701',
#  'SWK': '93556',
#  'W': '1616707',
#  'XPEV': '1810997',
#  'WST': '105770',
#  'KR': '56873',
#  'CBRE': '1138118',
#  'ARZGY': '1379235',
#  'DBOEY': '1437147',
#  'FERG': '1832433',
#  'FAST': '815556',
#  'VFC': '103379',
#  'AME': '1037868',
#  'EFX': '33185',
#  'ANSS': '1013462',
#  'MCK': '927653',
#  'SIVB': '719739',
#  'STT': '93751',
#  'AMP': '820027',
#  'FMX': '1061736',
#  'AVB': '915912',
#  'NDAQ': '1120193',
#  'ES': '72741',
#  'HUBS': '1404655',
#  'VRSK': '1442145',
#  'SLF': '1097362',
#  'EQR': '906107',
#  'TU': '868675',
#  'KEYS': '1601046',
#  'ZBRA': '877212',
#  'WEC': '783325',
#  'PATH': '1734722',
#  'ZBH': '1136869',
#  'GMAB': '1434265',
#  'ORAN': '1038143',
#  'ARE': '1035443',
#  'ALPMY': '1446390',
#  'SWKS': '4127',
#  'CHCJY': '1495687',
#  'LVS': '1300514',
#  'SYF': '1601712',
#  'GBERY': '1179029',
#  'MGDDY': '896076',
#  'WMB': '107263',
#  'TSN': '100493',
#  'LGFRY': '1554394',
#  'LUV': '92380',
#  'LH': '920148',
#  'TRUMY': '1446672',
#  'FNV': '1456346',
#  'GWLIF': '850918',
#  'BLL': '9389',
#  'MPLX': '1552000',
#  'BBY': '764478',
#  'DIA': '1041130',
#  'WEGZY': '1445166',
#  'SU': '311337',
#  'SAXPY': '1436778',
#  'CKHUY': '1637120',
#  'CJPRY': '1334687',
#  'PAYC': '1590955',
#  'HTHT': '1483994',
#  'SGEN': '1060736',
#  'WLTW': '1140536',
#  'PCAR': '75362',
#  'CRBJY': '1454471',
#  'CABHF': '1436647',
#  'ED': '1047862',
#  'CDW': '1402057',
#  'ANET': '1596532',
#  'AMADY': '1502104',
#  'TYIDY': '1130894',
#  'MDY': '936958',
#  'ZTCOY': '1445156',
#  'AJG': '354190',
#  'ALB': '915913',
#  'CCEP': '1650107',
#  'TEF': '814052',
#  'ZLNDY': '1638747',
#  'CCL': '815097',
#  'O': '726728',
#  'VLO': '1035002',
#  'FITB': '35527',
#  'SCHYY': '1491703',
#  'MXIM': '743316',
#  'EC': '1444406',
#  'KSU': '54480',
#  'IT': '749251',
#  'YAHOY': '1446437',
#  'SMNNY': '1640117',
#  'DB': '1159508',
#  'BILI': '1723690',
#  'CAIXY': '1535628',
#  'WY': '106535',
#  'IBKR': '1381197',
#  'TSCDY': '885834',
#  'YUMC': '1673358',
#  'BGNE': '1651308',
#  'GNRC': '1474735',
#  'XP': '1787425',
#  'FOJCY': '1436740',
#  'MGA': '749098',
#  'ET': '1276187',
#  'FTV': '1659166',
#  'CSX': '277948',
#  'BAESY': '895564',
#  'UMC': '1033767',
#  'DAL': '27904',
#  'RCI': '733099',
#  'VIAC': '813828',
#  'URI': '1067701',
#  'CAJ': '16988',
#  'EJPRY': '1093028',
#  'MMEX': '1440799',
#  'DOV': '29905',
#  'LI': '1791706',
#  'WAT': '1000697',
#  'HRL': '48465',
#  'VMC': '1396009',
#  'TLPFY': '1450682',
#  'ABC': '1140859',
#  'XNGSY': '1454948',
#  'YNDX': '1513845',
#  'RWEOY': '939380',
#  'SIRI': '908937',
#  'SONVY': '1450681',
#  'GASNY': '1269920',
#  'CUK': '1125259',
#  'ETSY': '1370637',
#  'CTRYY': '1462886',
#  'RYAAY': '1038683',
#  'NTRS': '73124',
#  'ANYYY': '1700171',
#  'HIG': '874766',
#  'FMS': '1333141',
#  'CERN': '804753',
#  'CS': '1159510',
#  'XYL': '1524472',
#  'HZNP': '1492426',
#  'SPLK': '1353283',
#  'MLM': '916076',
#  'DLTR': '935703',
#  'VRSN': '1014473',
#  'ZG': '1617640',
#  'RPRX': '1802768',
#  'EXR': '1289490',
#  'BIO': '12208',
#  'OKE': '1039684',
#  'MKC': '63754',
#  'SGSOY': '1069347',
#  'IP': '51434',
#  'CNHI': '1567094',
#  'DTE': '936340',
#  'WEICY': '1452191',
#  'CMAKY': '1453056',
#  'FANDY': '1454175',
#  'OXY': '797468',
#  'ALNY': '1178670',
#  'ZI': '1794515',
#  'AONNY': '1300175',
#  'TLK': '1001807',
#  'ZSHGY': '1495686',
#  'RNG': '1384905',
#  'GWW': '277135',
#  'SVNLY': '1448613',
#  'MDB': '1441816',
#  'OTSKY': '1544613',
#  'TRU': '1552033',
#  'ENPH': '1463101',
#  'AEE': '1002910',
#  'BURL': '1579298',
#  'TSCO': '916365',
#  'SSMXY': '1517231',
#  'PPL': '922224',
#  'DISH': '1001082',
#  'INVH': '1687229',
#  'AVTR': '1722482',
#  'K': '55067',
#  'XM': '1747748',
#  'TRMB': '864749',
#  'BKR': '1701605',
#  'ETR': '65984',
#  'HBAN': '49196',
#  'SUI': '912593',
#  'GIB': '1061574',
#  'MTSFY': '1446641',
#  'FTS': '1666175',
#  'IR': '1699150',
#  'FLT': '1175454',
#  'EXPE': '1324424',
#  'STE': '1757898',
#  'THLLY': '1722401',
#  'ZTO': '1677250',
#  'EIX': '827052',
#  'FRRVY': '1438571',
#  'MAA': '912595',
#  'SZKMY': '1263521',
#  'COO': '711404',
#  'PKX': '889132',
#  'CNCN': '1191334',
#  'LNG': '3570',
#  'IX': '1070304',
#  'TDOC': '1477449',
#  'DKNG': '1772757',
#  'VTR': '740260',
#  'QRVO': '1604778',
#  'EXPD': '746515',
#  'TDY': '1094285',
#  'CHD': '313927',
#  'CLX': '21076',
#  'FE': '1031296',
#  'BEKE': '1809587',
#  'FOXA': '1754301',
#  'MPWR': '1280452',
#  'CRL': '1100682',
#  'UCBJY': '1290640',
#  'KMX': '1170010',
#  'HES': '4447',
#  'NRILY': '1179493',
#  'PCG': '1004980',
#  'IMBBY': '1072670',
#  'PKI': '31791',
#  'STX': '1137789',
#  'CTLT': '1596783',
#  'ESS': '920522',
#  'SNMRY': '1437771',
#  'ULTA': '1403568',
#  'PPCCY': '1446747',
#  'RNECY': '1246135',
#  'TW': '1758730',
#  'APP': '1751008',
#  'BR': '1383312',
#  'CQP': '1383650',
#  'RCL': '884887',
#  'DPZ': '1286681',
#  'KEY': '91576',
#  'QSR': '1618756',
#  'WPM': '1323404',
#  'ALLY': '40729',
#  'POOL': '945841',
#  'CJEWY': '1555574',
#  'SSNC': '1402436',
#  'RF': '1281761',
#  'TER': '97210',
#  'HOLX': '859737',
#  'CINF': '20286',
#  'SYIEY': '1444718',
#  'HPE': '1645590',
#  'TYL': '860731',
#  'IMO': '49938',
#  'PODD': '1145197',
#  'MGM': '789570',
#  'GCTAY': '1158089',
#  'UI': '1511737',
#  'PEAK': '765880',
#  'DRE': '783280',
#  'PRDSY': '1527249',
#  'LU': '1816007',
#  'NVR': '906163',
#  'RJF': '720005',
#  'PPERY': '1461748',
#  'NVAX': '1000694',
#  'ASX': '1122411',
#  'DVN': '1090012',
#  'WDC': '106040',
#  'HAITY': '1553473',
#  'CFG': '759944',
#  'AMCR': '1748790',
#  'AKAM': '1086222',
#  'SKM': '1015650',
#  'BILL': '1786352',
#  'TTWO': '946581',
#  'PAGS': '1712807',
#  'TECH': '842023',
#  'JBHT': '728535',
#  'ON': '1097864',
#  'DGX': '1022079',
#  'CMS': '811156',
#  'LOGI': '1032975',
#  'DRI': '940944',
#  'AMC': '1411579',
#  'NTAP': '1002047',
#  'CE': '1306830',
#  'ROL': '84839',
#  'BXP': '1037540',
#  'CZR': '1590895',
#  'PFG': '1126328',
#  'GPC': '40987',
#  'GRUB': '1792627',
#  'WMG': '1319161',
#  'DT': '1773383',
#  'VTRS': '1792044',
#  'HDELY': '1400691',
#  'J': '52988',
#  'DVCMY': '1163417',
#  'HAL': '45012',
#  'MTB': '36270',
#  'AVY': '8818',
#  'TLSNY': '1169870',
#  'MKTX': '1278021',
#  'LYV': '1335258',
#  'SGIOY': '1281721',
#  'LSXMA': '1560385',
#  'BSY': '1031308',
#  'KB': '1445930',
#  'ALFVY': '863344',
#  'MKL': '1096343',
#  'CGHLY': '1550635',
#  'PBA': '1546066',
#  'AFRM': '1820953',
#  'TXG': '1770787',
#  'TFX': '96943',
#  'RKUNY': '1294591',
#  'XYIGY': '1508669',
#  'SHG': '1263043',
#  'CG': '1527166',
#  'IEX': '832101',
#  'COIHY': '1513977',
#  'UMICY': '1477038',
#  'NUAN': '1002517',
#  'ACGL': '947484',
#  'NICE': '1003935',
#  'BIP': '1406234',
#  'AGR': '1634997',
#  'SNN': '845982',
#  'WAB': '943452',
#  'LYFT': '1759509',
#  'LBTYA': '1570585',
#  'JHX': '1159152',
#  'CHKP': '1015922',
#  'HEI': '46619',
#  'WPP': '806968',
#  'TXT': '217346',
#  'VEDL': '1370431',
#  'TME': '1744676',
#  'CAG': '23217',
#  'BEN': '38777',
#  'KKOYY': '1436794',
#  'NNGRY': '1690981',
#  'SZLMY': '1438844',
#  'AES': '874761',
#  'WHLKF': '1449594',
#  'OMC': '29989',
#  'INCY': '879169',
#  'PPD': '1793294',
#  'VICI': '1705696',
#  'ELP': '1041792',
#  'TIF': '98246',
#  'SBHMY': '1604982',
#  'TCOM': '1269238',
#  'CKISY': '1065989',
#  'EXAS': '1124140',
#  'TSGTY': '939383',
#  'CVE': '1475260',
#  'PUBGY': '1050952',
#  'BRO': '79282',
#  'MAS': '62996',
#  'CDAY': '1725057',
#  'UDR': '74208',
#  'ARGX': '1697862',
#  'STNE': '1745431',
#  'EVRG': '1711269',
#  'ENTG': '1101302',
#  'FTCH': '1740915',
#  'EMN': '915389',
#  'ALSMY': '1062066',
#  'TTM': '926042',
#  'COUP': '1385867',
#  'BNTGY': '1533945',
#  'UPST': '1647639',
#  'STLD': '1022671',
#  'PTC': '857005',
#  'LNT': '352541',
#  'NMR': '1163653',
#  'LKQ': '1065696',
#  'NLOK': '849399',
#  'FUJHY': '800364',
#  'CAH': '721371',
#  'RH': '1528849',
#  'ELS': '895417',
#  'SMFKY': '1537547',
#  'SZSAY': '1444147',
#  'UAL': '100517',
#  'ABMD': '815094',
#  'ELAN': '1739104',
#  'ATASY': '1437775',
#  'SBNY': '1288784',
#  'CNP': '1130310',
#  'MOH': '1179929',
#  'SEDG': '1419612',
#  'IPG': '51644',
#  'IEP': '813762',
#  'ZEN': '1463172',
#  'OAOFY': '1058255',
#  'JBAXY': '1475011',
#  'OTEX': '1002638',
#  'CGNX': '851205',
#  'CCK': '1219601',
#  'L': '60086',
#  'WHR': '106640',
#  'MHK': '851968',
#  'GDRX': '1809519',
#  'SJR': '932872',
#  'MARUY': '801645',
#  'MASI': '937556',
#  'AMIGY': '1438930',
#  'SUZ': '909327',
#  'CLPXY': '1490083',
#  'AEM': '2809',
#  'NVCR': '1645113',
#  'SJM': '91419',
#  'PHM': '822416',
#  'EDNMY': '1581671',
#  'NTCO': '1776967',
#  'FBHS': '1519751',
#  'SQM': '909037',
#  'PLUG': '1093691',
#  'CPT': '906345',
#  'AVLR': '1348036',
#  'ENIA': '912505',
#  'ZLAB': '1704292',
#  'MRVI': '1823239',
#  'FDS': '1013237',
#  'FNF': '1331875',
#  'WPC': '1025378',
#  'RGEN': '730272',
#  'BZ': '1842827',
#  'DVA': '927066',
#  'ACH': '1161611',
#  'ACI': '1646972',
#  'SWMAY': '1011218',
#  'PKG': '75677',
#  'SOLVY': '930826',
#  'AAP': '1158449',
#  'HWM': '4281',
#  'KEP': '887225',
#  'APO': '1411494',
#  'AGL': '1831097',
#  'HAS': '46080',
#  'EQH': '1333986',
#  'BMRN': '1048477',
#  'YASKY': '1559460',
#  'PCTY': '1591698',
#  'CLVT': '1764046',
#  'PTAIY': '1455967',
#  'PWR': '1050915',
#  'VIV': '1066119',
#  'NWSA': '1564708',
#  'LDOS': '1336920',
#  'JXHLY': '1487533',
#  'WRK': '1732845',
#  'KIKOY': '1446656',
#  'CBOE': '1374310',
#  'KKPNY': '1001474',
#  'ESTC': '1707753',
#  'LNC': '59558',
#  'DISCA': '1437107',
#  'LUMN': '18926',
#  'FUTU': '1754581',
#  'PNR': '77360',
#  'CCHGY': '1558633',
#  'NDSN': '72331',
#  'GGG': '42888',
#  'RANJY': '1112439',
#  'ATO': '731802',
#  'IRM': '1020569',
#  'AMH': '1562401',
#  'XRAY': '818479',
#  'WRB': '11544',
#  'JKHY': '779152',
#  'CPB': '16732',
#  'FANG': '1539838',
#  'FICO': '814547',
#  'DQJCY': '1446597',
#  'ATUS': '1702780',
#  'GRFS': '1438569',
#  'UHAL': '4457',
#  'CLR': '732834',
#  'UHS': '352915',
#  'CXO': '1358071',
#  'LII': '1069202',
#  'PSMMY': '1439580',
#  'KOF': '910631',
#  'MTUAY': '1342237',
#  'MAOGY': '1437144',
#  'DAR': '916540',
#  'MOS': '1285785',
#  'CCOZY': '1398879',
#  'CLF': '764065',
#  'CTXS': '877890',
#  'FIVN': '1288847',
#  'SC': '1580608',
#  'AAL': '6201',
#  'JPXGY': '1600520',
#  'CGASY': '1555207',
#  'ICLR': '1060955',
#  'ALLE': '1579241',
#  'BRKR': '1109354',
#  'ATH': '1527469',
#  'DBX': '1467623',
#  'JLL': '1037976',
#  'SNA': '91440',
#  'LSPD': '1823306',
#  'TREX': '1069878',
#  'FIVE': '1177609',
#  'SBSW': '1786909',
#  'CHEOY': '1453930',
#  'WSM': '719955',
#  'FND': '1507079',
#  'TPR': '1116132',
#  'SBYSF': '1783546',
#  'CABO': '1632127',
#  'OSH': '1564406',
#  'CHRW': '1043277',
#  'FFIV': '1048695',
#  'ASAN': '1477720',
#  'TTC': '737758',
#  'ABMRF': '1784384',
#  'WTRG': '78128',
#  'ILIAY': '1570932',
#  'FMC': '37785',
#  'ZLIOY': '1546084',
#  'DECK': '910521',
#  'ARES': '1176948',
#  'AXON': '1069183',
#  'NLY': '1043219',
#  'WB': '1595761',
#  'GDDY': '1609711',
#  'SOFI': '1818874',
#  'BKI': '1627014',
#  'UWMC': '1783398',
#  'MTN': '812011',
#  'NDVLY': '800928',
#  'FRFHF': '915191',
#  'EMRAF': '1127248',
#  'TS': '1190723',
#  'PCOR': '1611052',
#  'TECK': '886986',
#  'QGEN': '1015820',
#  ...}

# %%
# Extracting relevant links

year = 2019
quarter = 'QTR2'

#get name of all filings 
download = requests.get(f'https://www.sec.gov/Archives/edgar/full-index/{year}/{quarter}/master.idx').content
download = download.decode("utf-8").split('\n')

# %%
# Checking Content of download
print(download[2001:2011])
# Out:
# ['1007499|IFS SECURITIES, INC|X-17A-5|2019-06-14|edgar/data/1007499/9999999997-19-005663.txt', '1007524|OSTERWEIS CAPITAL MANAGEMENT INC|13F-HR|2019-05-15|edgar/data/1007524/0001085146-19-001576.txt', '1007546|BATINOVICH ANDREW|4|2019-05-06|edgar/data/1007546/0001209191-19-027760.txt', '1007547|KLAUSMEYER KEVIN|4|2019-06-24|edgar/data/1007547/0001567619-19-013912.txt', '1007549|SOLCHER STEPHEN B|4|2019-04-25|edgar/data/1007549/0001593968-19-000988.txt', '1007549|SOLCHER STEPHEN B|4|2019-05-08|edgar/data/1007549/0001593968-19-001070.txt', '1007549|SOLCHER STEPHEN B|4|2019-05-24|edgar/data/1007549/0001593968-19-001207.txt', '1007549|SOLCHER STEPHEN B|4|2019-06-26|edgar/data/1007549/0001593968-19-001498.txt', '1007571|RIVERSOURCE OF NEW YORK VARIABLE ANNUITY ACCOUNT|485BPOS|2019-04-25|edgar/data/1007571/0001193125-19-119265.txt', '1007571|RIVERSOURCE OF NEW YORK VARIABLE ANNUITY ACCOUNT|485BPOS|2019-04-25|edgar/data/1007571/0001193125-19-119291.txt']

# %%
# build the first part of the url

filing = '10-K'
list_of_links = []

for item in download:
    if(filing in item): 
        #print('Found')
        #print(item)
        company = item
        company = company.strip()
        splitted_company = company.split('|')
        url = splitted_company[-1]
        list_of_links.append(url)
        
print('Total number of links captured are', len(list_of_links))
# Out:
# Total number of links captured are 1988

# %%
# Sample URL creation

url = list_of_links[5]
print(url)

url2 = url.split('-') 
url2 = url2[0] + url2[1] + url2[2]
url2 = url2.split('.txt')[0]
print(url2) #edgar/data/1326801/000132680120000076

to_get_html_site = 'https://www.sec.gov/Archives/' + url
data = requests.get(to_get_html_site).content
data = data.decode("utf-8") 
data = data.split('FILENAME>')
# print(data[1])
data = data[1].split('\n')[0]

url_to_use = 'https://www.sec.gov/Archives/'+ url2 + '/' + data
print(url_to_use)  # Returns a link like https://www.sec.gov/Archives/edgar/data/1001601/000149315219005484/form10-k.htm
# Out:
# edgar/data/1001601/0001493152-19-005484.txt
# edgar/data/1001601/000149315219005484
# https://www.sec.gov/Archives/edgar/data/1001601/000149315219005484/form10-k.htm

# %%
# Capturing the complete URL

url_list = []

for i in range(len(list_of_links)):
    print('Starting for', i)
    url = list_of_links[i]
    print(url) #edgar/data/1326801/0001326801-20-000076.txt

    url2 = url.split('-') 
    url2 = url2[0] + url2[1] + url2[2]
    url2 = url2.split('.txt')[0]
    #print(url2) #edgar/data/1326801/000132680120000076

    to_get_html_site = 'https://www.sec.gov/Archives/' + url
    data = requests.get(to_get_html_site).content
    data = data.decode("utf-8") 
    data = data.split('FILENAME>')
    #print(data[1])
    data = data[1].split('\n')[0]
    url_to_use = 'https://www.sec.gov/Archives/'+ url2 + '/'+data
    #print(url_to_use)
    url_list.append(url_to_use)
    
print(len(url_list))
# Out:
# Starting for 0
# edgar/data/1000045/0001564590-19-023956.txt
# Starting for 1
# edgar/data/1000683/0001213900-19-005351.txt
# Starting for 2
# edgar/data/1000694/0001144204-19-022376.txt
# Starting for 3
# edgar/data/1001463/0001185185-19-000474.txt
# Starting for 4
# edgar/data/1001601/0001493152-19-005718.txt
# Starting for 5
# edgar/data/1001601/0001493152-19-005484.txt
# Starting for 6
# edgar/data/1001601/0001493152-19-004537.txt
# Starting for 7
# edgar/data/1002047/0001564590-19-022779.txt
# Starting for 8
# edgar/data/1002135/0001002135-19-000017.txt
# Starting for 9
# edgar/data/1004434/0001004434-19-000011.txt
# Starting for 10
# edgar/data/1004724/0001564590-19-019674.txt
# Starting for 11
# edgar/data/1004724/0001564590-19-010589.txt
# Starting for 12
# edgar/data/1004980/0000950157-19-000501.txt
# Starting for 13
# edgar/data/1004989/0001437749-19-007807.txt
# Starting for 14
# edgar/data/1004989/0001437749-19-007194.txt
# Starting for 15
# edgar/data/1004989/0001437749-19-006183.txt
# Starting for 16
# edgar/data/1005011/0001005011-19-000009.txt
# Starting for 17
# edgar/data/1005229/0001005229-19-000153.txt
# Starting for 18
# edgar/data/100591/0001104659-19-020681.txt
# Starting for 19
# edgar/data/1006045/0001564590-19-013672.txt
# Starting for 20
# edgar/data/100625/0001493152-19-006003.txt
# Starting for 21
# edgar/data/100625/0001493152-19-004616.txt
# Starting for 22
# edgar/data/100716/0000100716-19-000017.txt
# Starting for 23
# edgar/data/1008586/0001558370-19-003142.txt
# Starting for 24
# edgar/data/1009759/0001558370-19-005619.txt
# Starting for 25
# edgar/data/1009891/0001213900-19-005962.txt
# Starting for 26
# edgar/data/1009891/0001213900-19-010014.txt
# Starting for 27
# edgar/data/1009891/0001213900-19-005550.txt
# Starting for 28
# edgar/data/1011395/0001376474-19-000095.txt
# Starting for 29
# edgar/data/1011395/0001376474-19-000066.txt
# Starting for 30
# edgar/data/1011662/0001654954-19-006480.txt
# Starting for 31
# edgar/data/1011662/0001654954-19-007433.txt
# Starting for 32
# edgar/data/1011662/0001654954-19-007421.txt
# Starting for 33
# edgar/data/1011662/0001654954-19-004069.txt
# Starting for 34
# edgar/data/1011662/0001654954-19-003726.txt
# Starting for 35
# edgar/data/1013606/0001013606-19-000081.txt
# Starting for 36
# edgar/data/1013606/0001013606-19-000059.txt
# Starting for 37
# edgar/data/1014052/0001213900-19-007224.txt
# Starting for 38
# edgar/data/1014111/0001493152-19-004550.txt
# Starting for 39
# edgar/data/1014763/0001014763-19-000004.txt
# Starting for 40
# edgar/data/101538/0001654954-19-003859.txt
# Starting for 41
# edgar/data/101538/0001654954-19-003748.txt
# Starting for 42
# edgar/data/101594/0001493152-19-004729.txt
# Starting for 43
# edgar/data/1016178/0001016178-19-000011.txt
# Starting for 44
# edgar/data/1016708/0001731122-19-000192.txt
# Starting for 45
# edgar/data/1016708/0001477932-19-001339.txt
# Starting for 46
# edgar/data/1017480/0001017480-19-000011.txt
# Starting for 47
# edgar/data/1017655/0001654954-19-003887.txt
# Starting for 48
# edgar/data/101829/0000101829-19-000009.txt
# Starting for 49
# edgar/data/101830/0000101830-19-000022.txt
# Starting for 50
# edgar/data/1018840/0001018840-19-000018.txt
# Starting for 51
# edgar/data/1019034/0001437749-19-006677.txt
# Starting for 52
# edgar/data/1019034/0001437749-19-006258.txt
# Starting for 53
# edgar/data/1019671/0001564590-19-011518.txt
# Starting for 54
# edgar/data/102037/0000102037-19-000022.txt
# Starting for 55
# edgar/data/102109/0001144204-19-032886.txt
# Starting for 56
# edgar/data/1021162/0001021162-19-000063.txt
# Starting for 57
# edgar/data/1021162/0001021162-19-000060.txt
# Starting for 58
# edgar/data/1021435/0001493152-19-004622.txt
# Starting for 59
# edgar/data/1022408/0001022408-19-000012.txt
# Starting for 60
# edgar/data/1022652/0001193125-19-129258.txt
# Starting for 61
# edgar/data/1023298/0001493152-19-004607.txt
# Starting for 62
# edgar/data/1023731/0001023731-19-000037.txt
# Starting for 63
# edgar/data/1024626/0001562884-19-000004.txt
# Starting for 64
# edgar/data/1029744/0001029744-19-000059.txt
# Starting for 65
# edgar/data/1030192/0001052918-19-000085.txt
# Starting for 66
# edgar/data/1030192/0001052918-19-000061.txt
# Starting for 67
# edgar/data/1031235/0001564590-19-010411.txt
# Starting for 68
# edgar/data/103145/0001558370-19-003746.txt
# Starting for 69
# edgar/data/1032975/0001032975-19-000027.txt
# Starting for 70
# edgar/data/103379/0000103379-19-000006.txt
# Starting for 71
# edgar/data/1036188/0001437749-19-007282.txt
# Starting for 72
# edgar/data/1037016/0001037016-19-000014.txt
# Starting for 73
# edgar/data/1037038/0001037038-19-000005.txt
# Starting for 74
# edgar/data/1037131/0001493152-19-004341.txt
# Starting for 75
# edgar/data/1037390/0001558370-19-002815.txt
# Starting for 76
# edgar/data/1038074/0001047469-19-002853.txt
# Starting for 77
# edgar/data/1039101/0001140361-19-008010.txt
# Starting for 78
# edgar/data/1040130/0001437749-19-010894.txt
# Starting for 79
# edgar/data/1040719/0001040719-19-000015.txt
# Starting for 80
# edgar/data/1040719/0001040719-19-000010.txt
# Starting for 81
# edgar/data/1040719/0001040719-19-000004.txt
# Starting for 82
# edgar/data/1040850/0001554795-19-000115.txt
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-8f55c80a4bf4> in <module>
#      18     data = data.split('FILENAME>')
#      19     #print(data[1])
# ---> 20     data = data[1].split('\n')[0]
#      21     url_to_use = 'https://www.sec.gov/Archives/'+ url2 + '/'+data
#      22     #print(url_to_use)
#
# IndexError: list index out of range

# %%
# No specific point of termination
print('Loop breaking at', i)
# Out:
# Loop breaking at 82

# %%
# URL index at which loop terminated

url = list_of_links[i]
print(url)

url2 = url.split('-') 
url2 = url2[0] + url2[1] + url2[2]
url2 = url2.split('.txt')[0]
print(url2) #edgar/data/1326801/000132680120000076

to_get_html_site = 'https://www.sec.gov/Archives/' + url
data = requests.get(to_get_html_site).content
data = data.decode("utf-8") 
data = data.split('FILENAME>')
# print(data[1])
data = data[1].split('\n')[0]

url_to_use = 'https://www.sec.gov/Archives/'+ url2 + '/' + data
print(url_to_use)  # Returns a link like https://www.sec.gov/Archives/edgar/data/1001601/000149315219005484/form10-k.htm
# Out:
# edgar/data/1040850/0001554795-19-000115.txt
# edgar/data/1040850/000155479519000115
# https://www.sec.gov/Archives/edgar/data/1040850/000155479519000115/agtk0503form10k.htm

# %%
# Inspecting data for ith index
print(data)
# Out:
# agtk0503form10k.htm
